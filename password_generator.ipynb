# %%
import random
def shuffle(string):
 temp=list(string)
 random.shuffle(temp)
 return ''.join(temp)
uppercaseLetter1=chr(random.randint(65,90))
uppercaseLetter2=chr(random.randint(65,90))
lowercaseLetter1=chr(random.randint(91,124))
lowercaseLetter2=chr(random.randint(91,124))
number1=str(random.randint(0,9))
number2=str(random.randint(0,9))
character1=str(chr(random.randint(0,64)))
character2=str(chr(random.randint(0,64)))
password=uppercaseLetter1+uppercaseLetter2+lowercaseLetter1+lowercaseLetter2+number1+number2+character1+character2
#print(password)
output=shuffle(password)
print("Password Generator")
print("GENERATED PASWORD:")
print(output)
# Out:
# Password Generator
# GENERATED PASWORD:
# y9C/A]7
